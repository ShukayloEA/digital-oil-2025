# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
df_static = pd.read_csv('changed_static_dataset_v2.csv')
df_dynamic = pd.read_excel('Dataset_dynamic_final.xlsx')

# %%
df_dynamic = df_dynamic.rename(columns={"Время":"ID скважины","Дебит жидкости (объёмный), м3/сут":"Время","Обводненность (объёмная), %":"Дебит жидкости (объёмный), м3/сут","Рбуф, атм":"Обводненность (объёмная), %","Давление линейное, атм":"Рбуф, атм","Давление на приеме насоса, атм":"Давление линейное, атм",
          "Загрузка ПЭД, %":"Давление на приеме насоса, атм","Попутный газ":"Загрузка ПЭД, %","Частота тока, Герц":"Попутный газ","Ток фазы А, A (ампер)":"Частота тока, Герц","Мощность активная, кВт":"Ток фазы А, A (ампер)","Напряжение, АВ Вольт":"Мощность активная, кВт",
          "P затрубное, атм":"Напряжение, АВ Вольт", "ID скважины":"P затрубное, атм"})

# %%
df = pd.merge(df_static, df_dynamic, on="ID скважины")

# %%
pd.set_option('display.max_columns', None)
df.describe(include='all')
# Out:
#          ID скважины         name  rate_nom_sm3day  rate_opt_min_sm3day  \
# count   18584.000000        18584     18584.000000         18584.000000
# unique           NaN           52              NaN                  NaN
# top              NaN  ЭЦНКИД5-80И              NaN                  NaN
# freq             NaN         1404              NaN                  NaN
# mean    14464.315110          NaN       103.824419            76.256296
# std      4963.652259          NaN        54.312224            43.013996
# min     10001.000000          NaN        35.000000            22.000000
# 25%     10023.000000          NaN        66.000000            48.000000
# 50%     10054.000000          NaN        80.000000            60.000000
# 75%     20013.000000          NaN       125.000000            95.000000
# max     20040.000000          NaN       320.000000           250.000000
#
#         rate_opt_max_sm3day  freq_Hz  \
# count          18584.000000  18584.0
# ...

# %%
i = 0
for x in df.isnull().sum():
    print(f'{x},    {df.columns[i]}')
    i+=1
# Out:
# 0,    ID скважины
# 0,    name
# 0,    rate_nom_sm3day
# 0,    rate_opt_min_sm3day
# 0,    rate_opt_max_sm3day
# 0,    freq_Hz
# 0,    rate_points
# 0,    head_points
# 0,    power_points
# 0,    eff_points
# 0,    stages_max
# 0,    rate_max_sm3day
# 0,    slip_nom_rpm
# 0,    eff_max
# 0,    manufacturer
# 0,    name_PED
# 0,    d_motor_mm
# 0,    motor_nom_i
# 0,    motor_amp_idle
# 0,    motor_nom_power
# 0,    NKT_bottom_depth
# 0,    NKT_sections_info
# 0,    NKT_roughness
# 0,    motor_nom_freq
# 0,    load_points
# 0,    amperage_points
# 0,    cosf_points
# 0,    eff_points_PED
# 0,    rpm_points
# 0,    measured
# 0,    absolute
# 0,    bottom_depth
# 0,    sections_info
# 0,    roughness
# 0,    NKT_bottom_depth.1
# 0,    NKT_sections_info.1
# 0,    NKT_roughness.1
# 0,    Пакер
# 0,    Количество ступеней насоса
# 0,    k_gas_sep
# 0,    КПД станции управления
# 0,    КПД трансформатора
# 0,    Глубина установки насоса
# 0,    Удельное сопротивление кабеля
# ...

# %%
df.drop(columns=["freq_Hz", "name", "rate_opt_min_sm3day", "rate_opt_max_sm3day", "absolute",
                 "rate_points", "head_points", "power_points", "eff_points", "stages_max", "rate_max_sm3day", "manufacturer", 
                 "name_PED", "d_motor_mm", "NKT_bottom_depth", "NKT_sections_info", "load_points", "amperage_points", "cosf_points", "eff_points_PED",
                 "rpm_points", "sections_info", "NKT_bottom_depth.1", "NKT_sections_info.1", "NKT_roughness.1", "Длина кабеля", "Время"], inplace=True)

# %%
df = df.dropna() # убрать оставшиеся пропущенные значения

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17667 entries, 0 to 18583
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID скважины                        17667 non-null  int64
#  1   rate_nom_sm3day                    17667 non-null  float64
#  2   slip_nom_rpm                       17667 non-null  float64
#  3   eff_max                            17667 non-null  float64
#  4   motor_nom_i                        17667 non-null  float64
#  5   motor_amp_idle                     17667 non-null  float64
#  6   motor_nom_power                    17667 non-null  float64
#  7   NKT_roughness                      17667 non-null  float64
#  8   motor_nom_freq                     17667 non-null  float64
#  9   measured                           17667 non-null  float64
#  10  bottom_depth                       17667 non-null  float64
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of        ID скважины  rate_nom_sm3day  slip_nom_rpm  eff_max  motor_nom_i  \
# 0            10001            200.0     48.616667   0.6408         59.0
# 1            10001            200.0     48.616667   0.6408         59.0
# 2            10001            200.0     48.616667   0.6408         59.0
# 3            10001            200.0     48.616667   0.6408         59.0
# 4            10001            200.0     48.616667   0.6408         59.0
# ...            ...              ...           ...      ...          ...
# 18579        20040             80.0     48.500000   0.5500         30.8
# 18580        20040             80.0     48.500000   0.5500         30.8
# 18581        20040             80.0     48.500000   0.5500         30.8
# 18582        20040             80.0     48.500000   0.5500         30.8
# 18583        20040             80.0     48.500000   0.5500         30.8
#
#        motor_amp_idle  motor_nom_power  NKT_roughness  motor_nom_freq  \
# ...

# %%
variation_gap = 0.2 # после какого уровня корреляции мы удоляем столбец: 1 - variation_gap
# получить коррелируюющие пары
p = np.argwhere(np.triu(np.isclose(corr2_coeff(X_train_processed.T,X_train_processed.T),1, atol=variation_gap),1))
# удалить коррелирующие столбцы
X_train_processed = np.delete(X_train_processed,p[:,1],axis=1)
X_test_processed = np.delete(X_test_processed,p[:,1],axis=1)

# %%
df.to_csv('Train_first_version.csv', encoding='utf-8-sig')
